# %%
from sklearn.datasets import make_multilabel_classification

# this will generate a random multi-label dataset
X, y = make_multilabel_classification(sparse = True, n_labels = 20,
return_indicator = 'sparse', allow_unlabeled = False)

# %%
from skmultilearn.problem_transform import LabelPowerset
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.cluster import IGraphLabelCooccurenceClusterer
from skmultilearn.ensemble import LabelSpacePartitioningClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-5ec6d4b44ab0> in <module>()
#       4 from sklearn.ensemble import RandomForestClassifier
#       5 from skmultilearn.problem_transform import LabelPowerset
# ----> 6 from skmultilearn.cluster import IGraphLabelCooccurenceClusterer
#       7 from skmultilearn.ensemble import LabelSpacePartitioningClassifier
#
# ~/anaconda3/lib/python3.6/site-packages/skmultilearn/cluster/__init__.py in <module>()
#       6 from .base import LabelSpaceClustererBase
#       7 from .base import LabelCooccurenceClustererBase
# ----> 8 from .graphtool import GraphToolCooccurenceClusterer
#       9 from .igraph import IGraphLabelCooccurenceClusterer
#      10 from .matrix import MatrixLabelSpaceClusterer
#
# ~/anaconda3/lib/python3.6/site-packages/skmultilearn/cluster/graphtool.py in <module>()
#       5 import copy
#       6 import numpy as np
# ----> 7 import graph_tool.all as gt
#       8
#       9
#
# ModuleNotFoundError: No module named 'graph_tool'

# %%
classifier = LabelPowerset(GaussianNB())

# %%
score = cross_val_score(classifier,X,y)
print("Classifier: {0}".format(score.mean()))
# Out:
# Classifier: 0.19933333333333333

# %%
import pandas as pd
import scipy
from scipy.io import arff
data, meta = scipy.io.arff.loadarff('yeast/yeast-train.arff')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#        Att1      Att2      Att3      Att4      Att5      Att6      Att7  \
# 0  0.093700  0.139771  0.062774  0.007698  0.083873 -0.119156  0.073305
# 1 -0.022711 -0.050504 -0.035691 -0.065434 -0.084316 -0.378560  0.038212
# 2 -0.090407  0.021198  0.208712  0.102752  0.119315  0.041729 -0.021728
# 3 -0.085235  0.009540 -0.013228  0.094063 -0.013592 -0.030719 -0.116062
# 4 -0.088765 -0.026743  0.002075 -0.043819 -0.005465  0.004306 -0.055865
#
#        Att8      Att9     Att10   ...     Class5  Class6  Class7  Class8  \
# 0  0.005510  0.027523  0.043477   ...       b'0'    b'0'    b'0'    b'0'
# 1  0.085770  0.182613 -0.055544   ...       b'0'    b'0'    b'1'    b'1'
# 2  0.019603 -0.063853 -0.053756   ...       b'0'    b'0'    b'0'    b'0'
# 3 -0.131674 -0.165448 -0.123053   ...       b'0'    b'0'    b'0'    b'0'
# 4 -0.071484 -0.159025 -0.111348   ...       b'0'    b'0'    b'0'    b'0'
#
#    Class9  Class10  Class11  Class12  Class13  Class14
# 0    b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 1    b'0'     b'0'     b'0'     b'1'     b'1'     b'0'
# 2    b'0'     b'0'     b'0'     b'1'     b'1'     b'0'
# 3    b'0'     b'0'     b'0'     b'1'     b'1'     b'1'
# 4    b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
#
# [5 rows x 117 columns]

# %%
X = df.loc[:, 'Att1':'Att103']
y = df.loc[:,'Class1':'Class14'].astype(int)
